# %% [markdown]
# # Fingerprint Feature Extraction

# %% [markdown]
# ### Introduction:
#
# Fingerprint biometrics involve: Image Acquisition, Image Enhancing, Feature extraction and matching with template. Since the dataset has unique fingerprints I will implement feature extraction and different techniques for enhancing images such as Edge detection, adaptive thresholding. Feature extraction constitutes of Ridge detection (level 1 feature) and Minutiae extraction (level 3 feature) to generate a template after whicha query image is matched using the metric ROC AUC curve.

# %% [markdown]
# ### Dependencies and Data

# %%
import numpy as np
import glob
import random
import imageio
import PIL, cv2
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
from skimage.morphology import convex_hull_image, erosion
from skimage.morphology import square
import matplotlib.image as mpimg
import skimage
import math
from scipy.ndimage.filters import convolve
from PIL import Image,ImageFilter
from skimage.feature import hessian_matrix, hessian_matrix_eigvals
# Out:
# C:\Users\avina\AppData\Local\Temp\ipykernel_26392\2669811142.py:14: DeprecationWarning: Please use `convolve` from the `scipy.ndimage` namespace, the `scipy.ndimage.filters` namespace is deprecated.
#   from scipy.ndimage.filters import convolve

# %%
import os

# Provide a valid directory path with backslashes
DATA_DIR = "D:\\idk\\CRYPTo\\fingerprints"
tiff_files = list(glob.glob(os.path.join(DATA_DIR, "*.tif")))
num_images = len(tiff_files)

print("Number of TIFF images found:", num_images)
print("List of TIFF files:")
print(tiff_files)
# Out:
# Number of TIFF images found: 80
# List of TIFF files:
# ['D:\\idk\\CRYPTo\\fingerprints\\101_1.tif', 'D:\\idk\\CRYPTo\\fingerprints\\101_2.tif', 'D:\\idk\\CRYPTo\\fingerprints\\101_3.tif', 'D:\\idk\\CRYPTo\\fingerprints\\101_4.tif', 'D:\\idk\\CRYPTo\\fingerprints\\101_5.tif', 'D:\\idk\\CRYPTo\\fingerprints\\101_6.tif', 'D:\\idk\\CRYPTo\\fingerprints\\101_7.tif', 'D:\\idk\\CRYPTo\\fingerprints\\101_8.tif', 'D:\\idk\\CRYPTo\\fingerprints\\102_1.tif', 'D:\\idk\\CRYPTo\\fingerprints\\102_2.tif', 'D:\\idk\\CRYPTo\\fingerprints\\102_3.tif', 'D:\\idk\\CRYPTo\\fingerprints\\102_4.tif', 'D:\\idk\\CRYPTo\\fingerprints\\102_5.tif', 'D:\\idk\\CRYPTo\\fingerprints\\102_6.tif', 'D:\\idk\\CRYPTo\\fingerprints\\102_7.tif', 'D:\\idk\\CRYPTo\\fingerprints\\102_8.tif', 'D:\\idk\\CRYPTo\\fingerprints\\103_1.tif', 'D:\\idk\\CRYPTo\\fingerprints\\103_2.tif', 'D:\\idk\\CRYPTo\\fingerprints\\103_3.tif', 'D:\\idk\\CRYPTo\\fingerprints\\103_4.tif', 'D:\\idk\\CRYPTo\\fingerprints\\103_5.tif', 'D:\\idk\\CRYPTo\\fingerprints\\103_6.tif', 'D:\\idk\\CRYPTo\\fingerprints\\103_7.tif', 'D:\\idk\\CRYPTo\\fingerprints\\103_8.tif', 'D:\\idk\\CRYPTo\\fingerprints\\104_1.tif', 'D:\\idk\\CRYPTo\\fingerprints\\104_2.tif', 'D:\\idk\\CRYPTo\\fingerprints\\104_3.tif', 'D:\\idk\\CRYPTo\\fingerprints\\104
# %% [markdown]
# ### Displaying random images from data

# %%
random.seed(42)

r = random.randint(0,num_images)
display_list = tiff_files[r:r+3]

image1 = imageio.imread(display_list[0])
image2 = imageio.imread(display_list[1])
image3 = imageio.imread(display_list[2])

fig, axes = plt.subplots(1,3,figsize = (16,16));
axes[0].imshow(image1);
axes[1].imshow(image2);
axes[2].imshow(image3);
# Out:
# C:\Users\avina\AppData\Local\Temp\ipykernel_26392\1845255466.py:6: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image1 = imageio.imread(display_list[0])
# C:\Users\avina\AppData\Local\Temp\ipykernel_26392\1845255466.py:7: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image2 = imageio.imread(display_list[1])
# C:\Users\avina\AppData\Local\Temp\ipykernel_26392\1845255466.py:8: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image3 = imageio.imread(display_list[2])

# %% [markdown]
# ### Image Transforms
#
# 1. Image Smoothening
# 2. Thresholding
# 3. Edge Detection
#
# Image enhancement and preprocessing techniques such as smoothing, thresholding and edge detection are used to make features more prominent in data for extraction to be more accurate.

# %%
gauss_blur = cv2.GaussianBlur(image1,(1,1),0)
median_blur = cv2.medianBlur(image1,1)

fig, axes = plt.subplots(1,3,figsize = (16,16));
axes[0].set_title("original Image");
axes[0].imshow(image1);
axes[1].set_title("Gaussian Blurred Image");
axes[1].imshow(gauss_blur);
axes[2].set_title("Median Blurred Image");
axes[2].imshow(median_blur);

# %% [markdown]
# #### Histograms

# %%
fig, axes = plt.subplots(1,3,figsize = (18,5))
axes[0].hist(image1.ravel(), bins=256, color ="r");
axes[1].hist(image2.ravel(), bins=256);
axes[2].hist(image3.ravel(), bins=256, color ="g");

# %% [markdown]
# #### Data seems to be almost binary - implementing mean and adaptive thresholding

# %%
# mean thresholding - gives bad results
THRESHOLD1 = image1.mean()
THRESHOLD2 = image2.mean()
THRESHOLD3 = image3.mean()

image1 = np.array(image1 > THRESHOLD1).astype(int) * 255
image2 = np.array(image2 > THRESHOLD2).astype(int) * 254
image3 = np.array(image3 > THRESHOLD3).astype(int) * 254

fig, axes = plt.subplots(1,3,figsize = (16,16));
axes[0].imshow(image1);
axes[1].imshow(image2);
axes[2].imshow(image3);

# %%
# Adaptive thresholding from OpenCV library - better than Mean Thresholding

img1 = cv2.imread(display_list[0],0)
img2 = cv2.imread(display_list[1],0)
img3 = cv2.imread(display_list[2],0)

# Otsu's thresholding
ret1,th1 = cv2.threshold(img1,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
ret2,th2 = cv2.threshold(img2,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
ret3,th3 = cv2.threshold(img3,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)

fig, axes = plt.subplots(1,3,figsize = (12,12));
axes[0].set_title("Otsu's thresholding - Image 1");
axes[0].imshow(th2);
axes[1].set_title("Otsu's thresholding - Image 2");
axes[1].imshow(th2);
axes[2].set_title("Otsu's thresholding - Image 3");
axes[2].imshow(th2);

# %% [markdown]
# ### Edge detection:

# %%
# convert to grayscale
img_name = display_list[0]
gray_img_array = np.array(Image.open(img_name).convert('P'))

# %% [markdown]
# Robert, Sobel, Prewitt Filters

# %%
vertical_robert_filter = np.array([[1,0],[0,-1]])
horizontal_robert_filter = np.array([[0,1],[-1,0]])

vertical_sobel_filter = np.array([[-1,0,1],[-2,0,2],[-1,0,1]])
horizontal_sobel_filter = np.array([[-1,-2,-1],[0,0,0],[1,2,1]])

vertical_prewitt_filter = np.array([[-1,0,1],[-1,0,1],[-1,0,1]])
horizontal_prewitt_filter = np.array([[-1,-1,-1],[0,0,0],[1,1,1]])

print("vertical robert filter\n",vertical_robert_filter )
print("horizontal robert filter\n",horizontal_robert_filter)
print("vertical sobel filter: \n", vertical_sobel_filter)
print("horizontal sobel filter: \n", horizontal_sobel_filter)

print("vertical prewitt filter: \n", vertical_prewitt_filter)
print("horizontal prewitt filter: \n", horizontal_prewitt_filter)
# Out:
# vertical robert filter
#  [[ 1  0]
#  [ 0 -1]]
# horizontal robert filter
#  [[ 0  1]
#  [-1  0]]
# vertical sobel filter:
#  [[-1  0  1]
#  [-2  0  2]
#  [-1  0  1]]
# horizontal sobel filter:
#  [[-1 -2 -1]
#  [ 0  0  0]
#  [ 1  2  1]]
# vertical prewitt filter:
#  [[-1  0  1]
#  [-1  0  1]
#  [-1  0  1]]
# horizontal prewitt filter:
#  [[-1 -1 -1]
#  [ 0  0  0]
#  [ 1  1  1]]

# %%
# implementing:
gray_img = Image.fromarray(gray_img_array)

convolved_img1 = convolve(gray_img,vertical_robert_filter)
convolved_img1 = convolve(convolved_img1,horizontal_robert_filter)

convolved_img2 = convolve(gray_img,vertical_sobel_filter)
convolved_img2 = convolve(convolved_img2,horizontal_sobel_filter)

convolved_img3 =  convolve(gray_img,vertical_prewitt_filter )
convolved_img3 =  convolve(gray_img,horizontal_prewitt_filter )

# %%
fig, axes = plt.subplots(1,3,figsize = (12,12));
axes[0].set_title("Robert");
axes[0].imshow(convolved_img1);
axes[1].set_title("Sobel");
axes[1].imshow(convolved_img2);
axes[2].set_title("Prewitt");
axes[2].imshow(convolved_img3);

# %% [markdown]
# ### Ridge Detection

# %%
src_path = img_name

def detect_ridges(gray, sigma= 0.1):
    H_elems = hessian_matrix(gray, sigma=sigma, order='rc')
    maxima_ridges, minima_ridges = hessian_matrix_eigvals(H_elems)
    return maxima_ridges, minima_ridges

def plot_images(*images):
    images = list(images)
    n = len(images)
    fig, ax = plt.subplots(ncols=n, sharey=True, figsize = (12,12))
    for i, img in enumerate(images):
        ax[i].imshow(img, cmap='gray')
        ax[i].axis('off')
    plt.subplots_adjust(left=0.03, bottom=0.03, right=0.97, top=0.97)
    plt.show()

img = cv2.imread(src_path, 0) # 0 imports a grayscale
if img is None:
    raise(ValueError(f"Image didn\'t load. Check that '{src_path}' exists."))

a, b = detect_ridges(img, sigma=0.15)

plot_images(img, a, b)
# Out:
# C:\Users\avina\AppData\Local\Temp\ipykernel_26392\2710860095.py:4: FutureWarning: use_gaussian_derivatives currently defaults to False, but will change to True in a future version. Please specify this argument explicitly to maintain the current behavior
#   H_elems = hessian_matrix(gray, sigma=sigma, order='rc')

# %% [markdown]
# ### Termination and Bifurcation detection and Minutiae Extraction
#
# The given code extracts features like Termination, Bifurcation and Minutiae from finger prints, the output is shown below the code:

# %%
def getTerminationBifurcation(img, mask):
    img = img == 255;
    (rows, cols) = img.shape;
    minutiaeTerm = np.zeros(img.shape);
    minutiaeBif = np.zeros(img.shape);
    
    for i in range(1,rows-1):
        for j in range(1,cols-1):
            if(img[i][j] == 1):
                block = img[i-1:i+2,j-1:j+2];
                block_val = np.sum(block);
                if(block_val == 2):
                    minutiaeTerm[i,j] = 1;
                elif(block_val == 4):
                    minutiaeBif[i,j] = 1;
    
    mask = convex_hull_image(mask>0)
    mask = erosion(mask, square(5))         
    minutiaeTerm = np.uint8(mask)*minutiaeTerm
    return(minutiaeTerm, minutiaeBif)

# %%
class MinutiaeFeature(object):
    def __init__(self, locX, locY, Orientation, Type):
        self.locX = locX;
        self.locY = locY;
        self.Orientation = Orientation;
        self.Type = Type;

def computeAngle(block, minutiaeType):
    angle = 0
    (blkRows, blkCols) = np.shape(block);
    CenterX, CenterY = (blkRows-1)/2, (blkCols-1)/2
    if(minutiaeType.lower() == 'termination'):
        sumVal = 0;
        for i in range(blkRows):
            for j in range(blkCols):
                if((i == 0 or i == blkRows-1 or j == 0 or j == blkCols-1) and block[i][j] != 0):
                    angle = -math.degrees(math.atan2(i-CenterY, j-CenterX))
                    sumVal += 1
                    if(sumVal > 1):
                        angle = float('nan');
        return(angle)
    elif(minutiaeType.lower() == 'bifurcation'):
        (blkRows, blkCols) = np.shape(block);
        CenterX, CenterY = (blkRows - 1) / 2, (blkCols - 1) / 2
        angle = []
        sumVal = 0;
        for i in range(blkRows):
            for j in range(blkCols):
                if ((i == 0 or i == blkRows - 1 or j == 0 or j == blkCols - 1) and block[i][j] != 0):
                    angle.append(-math.degrees(math.atan2(i - CenterY, j - CenterX)))
                    sumVal += 1
        if(sumVal != 3):
            angle = float('nan')
        return(angle)


def extractMinutiaeFeatures(skel, minutiaeTerm, minutiaeBif):
    FeaturesTerm = []

    minutiaeTerm = skimage.measure.label(minutiaeTerm, connectivity=2);
    RP = skimage.measure.regionprops(minutiaeTerm)
    
    WindowSize = 2          
    FeaturesTerm = []
    for i in RP:
        (row, col) = np.int16(np.round(i['Centroid']))
        block = skel[row-WindowSize:row+WindowSize+1, col-WindowSize:col+WindowSize+1]
        angle = computeAngle(block, 'Termination')
        FeaturesTerm.append(MinutiaeFeature(row, col, angle, 'Termination'))

    FeaturesBif = []
    minutiaeBif = skimage.measure.label(minutiaeBif, connectivity=2);
    RP = skimage.measure.regionprops(minutiaeBif)
    WindowSize = 1 
    for i in RP:
        (row, col) = np.int16(np.round(i['Centroid']))
        block = skel[row-WindowSize:row+WindowSize+1, col-WindowSize:col+WindowSize+1]
        angle = computeAngle(block, 'Bifurcation')
        FeaturesBif.append(MinutiaeFeature(row, col, angle, 'Bifurcation'))
    return(FeaturesTerm, FeaturesBif)

def ShowResults(skel, TermLabel, BifLabel):
    minutiaeBif = TermLabel * 0;
    minutiaeTerm = BifLabel * 0;

    (rows, cols) = skel.shape
    DispImg = np.zeros((rows, cols, 3), np.uint8)
    DispImg[:, :, 0] = skel;
    DispImg[:, :, 1] = skel;
    DispImg[:, :, 2] = skel;

    RP = skimage.measure.regionprops(BifLabel)
    for idx, i in enumerate(RP):
        (row, col) = np.int16(np.round(i['Centroid']))
        minutiaeBif[row, col] = 1;
        (rr, cc) = skimage.draw.circle_perimeter(row, col, 1);
        skimage.draw.set_color(DispImg, (rr, cc), (255, 0, 0));

    RP = skimage.measure.regionprops(TermLabel)
    for idx, i in enumerate(RP):
        (row, col) = np.int16(np.round(i['Centroid']))
        minutiaeTerm[row, col] = 1;
        (rr, cc) = skimage.draw.circle_perimeter(row, col, 1);
        skimage.draw.set_color(DispImg, (rr, cc), (0, 0, 255));
        
    plt.figure(figsize=(6,6))
    plt.title("Minutiae extraction results")
    plt.imshow(DispImg)

# %%
img_name = display_list[1]
img = cv2.imread(img_name,0);
img = np.array(img > THRESHOLD1).astype(int)
skel = skimage.morphology.skeletonize(img)
skel = np.uint8(skel)*255;
mask = img*255;

(minutiaeTerm, minutiaeBif) = getTerminationBifurcation(skel, mask);
FeaturesTerm, FeaturesBif = extractMinutiaeFeatures(skel, minutiaeTerm, minutiaeBif)
BifLabel = skimage.measure.label(minutiaeBif, connectivity=1);
TermLabel = skimage.measure.label(minutiaeTerm, connectivity=1);
ShowResults(skel, TermLabel, BifLabel)

# %%
import os
import pickle

# Initialize a list to store the minutiae results for all images
all_minutiae_results = []

# Loop through your images and extract minutiae results for each
for img_name in display_list:
    img = cv2.imread(img_name, 0)
    img = np.array(img > THRESHOLD1).astype(int)
    skel = skimage.morphology.skeletonize(img)
    skel = np.uint8(skel) * 255
    mask = img * 255

    (minutiaeTerm, minutiaeBif) = getTerminationBifurcation(skel, mask)
    FeaturesTerm, FeaturesBif = extractMinutiaeFeatures(skel, minutiaeTerm, minutiaeBif)
    BifLabel = skimage.measure.label(minutiaeBif, connectivity=1)
    TermLabel = skimage.measure.label(minutiaeTerm, connectivity=1)

    # Store the minutiae results for this image in a dictionary
    image_minutiae_results = {
        'ImageName': img_name,
        'FeaturesTerm': FeaturesTerm,
        'FeaturesBif': FeaturesBif,
        'BifLabel': BifLabel,
        'TermLabel': TermLabel
    }

    all_minutiae_results.append(image_minutiae_results)


# Get the current working directory
script_directory = os.getcwd()

# Specify the filename for the binary file in the same directory
fingerprint_binary_details = os.path.join(script_directory, "all_minutiae_results.pkl")

# Serialize and save the combined results for all images
with open(fingerprint_binary_details, 'wb') as file:
    pickle.dump(all_minutiae_results, file)

print("All minutiae results saved to", fingerprint_binary_details)
# Out:
# All minutiae results saved to d:\idk\CRYPTo\all_minutiae_results.pkl

# %%
import os
import pickle

# Get the current working directory
script_directory = os.getcwd()

# Specify the filename for the binary file in the same directory
fingerprint_binary_details = os.path.join(script_directory, "all_minutiae_results.pkl")

# Load the data from the binary file
with open(fingerprint_binary_details, 'rb') as file:
    all_minutiae_results = pickle.load(file)

# Now you can access and view the contents of `all_minutiae_results`
# Location X: 292, Location Y: 64, Orientation: [90.0, -0.0, -90.0], Type: Bifurcation
# Location X: 291, Location Y: 107, Orientation: [90.0, -135.0, -90.0], Type: Bifurcation
# Location X: 291, Location Y: 118, Orientation: [90.0, -180.0, -0.0], Type: Bifurcation
# Location X: 291, Location Y: 147, Orientation: [135.0, -0.0, -135.0], Type: Bifurcation
# Location X: 292, Location Y: 197, Orientation: [90.0, -180.0, -90.0], Type: Bifurcation
# Location X: 292, Location Y: 247, Orientation: [90.0, -0.0, -135.0], Type: Bifurcation
# Location X: 292, Location Y: 249, Orientation: [90.0, -180.0, -45.0], Type: Bifurcation
# Location X: 293, Location Y: 51, Orientation: [90.0, -180.0, -45.0], Type: Bifurcation
# Location X: 292, Location Y: 165, Orientation: [45.0, -180.0, -45.0], Type: Bifurcation
# Location X: 292, Location Y: 211, Orientation: [90.0, -135.0, -45.0], Type: Bifurcation
# Location X: 294, Location Y: 5, Orientation: [90.0, -180.0, -90.0], Type: Bifurcation
# Location X: 293, Location Y: 43, Orientation: [-180.0, -0.0, -90.0], Type: Bifurcation
# Location X: 293, Location Y: 108, Orientation: [135.0, -180.0, -0.0], Type: Bifurcation
# Location X: 293, Location Y: 112, Orientation: [45.0, -180.0, -45.0], Type: Bifurcation
# Location X: 294, Location Y: 144, Orientation: [90.0, -180.0, -90.0], Type: Bifurcation
# Location X: 295, Location Y: 68, Orientation: [90.0, -180.0, -90.0], Type: Bifurcation
# Location X: 294, Location Y: 89, Orientation: [90.0, -135.0, -90.0], Type: Bifurcation
# Location X: 294, Location Y: 135, Orientation: [90.0, -180.0, -0.0], Type: Bifurcation
# Location X: 294, Location Y: 239, Orientation: [135.0, -0.0, -135.0], Type: Bifurcation
# Location X: 296, Location Y: 42, Orientation: [45.0, -0.0, -90.0], Type: Bifurcation
# Location X: 295, Location Y: 64, Orientation: [90.0, -180.0, -0.0], Type: Bifurcation
# Location X: 296, Location Y: 86, Orientation: [45.0, -90.0, -45.0], Type: Bifurcation
# Location X: 295, Location Y: 132, Orientation: [135.0, -0.0, -135.0], Type: Bifurcation
# Location X: 296, Location Y: 214, Orientation: [90.0, -0.0, -135.0], Type: Bifurcation
# Location X: 296, Location Y: 11, Orientation: [45.0, -180.0, -90.0], Type: Bifurcation
# Location X: 297, Location Y: 80, Orientation: [90.0, -180.0, -45.0], Type: Bifurcation
# Location X: 297, Location Y: 74, Orientation: [90.0, -180.0, -0.0], Type: Bifurcation
# Location X: 297, Location Y: 88, Orientation: [90.0, -180.0, -0.0], Type: Bifurcation
# Location X: 297, Location Y: 90, Orientation: [90.0, -180.0, -0.0], Type: Bifurcation
# Location X: 298, Location Y: 122, Orientation: [90.0, -180.0, -0.0], Type: Bifurcation

# %%
import cv2
import numpy as np

# Load the minutiae data from the binary file
with open("all_minutiae_results.pkl", "rb") as file:
    all_minutiae_results = pickle.load(file)

# Create a directory to store the binary images if it doesn't exist
output_directory = "binary_images"
os.makedirs(output_directory, exist_ok=True)

# Loop through the minutiae data for each image
for idx, image_data in enumerate(all_minutiae_results):
    # Create a black image with the same size as the original fingerprint image
    height, width = cv2.imread(image_data['ImageName'], 0).shape
    binary_image = np.zeros((height, width), dtype=np.uint8)

    # Get the termination and bifurcation minutiae locations
    terminations = image_data['FeaturesTerm']
    bifurcations = image_data['FeaturesBif']

    # Set the pixel values at minutiae locations to 255 (white)
    for minutiae in terminations:
        x, y = minutiae.locX, minutiae.locY
        binary_image[x, y] = 255

    for minutiae in bifurcations:
        x, y = minutiae.locX, minutiae.locY
        binary_image[x, y] = 255

    # Save the binary image with a unique filename
    binary_image_filename = os.path.join(output_directory, f"binary_image_{idx + 1}.png")
    cv2.imwrite(binary_image_filename, binary_image)

print(f"All binary images saved in the '{output_directory}' directory.")
# Out:
# All binary images saved in the 'binary_images' directory.

# %%
import cv2
import numpy as np
import os

# Load the minutiae data from the binary file
with open("all_minutiae_results.pkl", "rb") as file:
    all_minutiae_results = pickle.load(file)

# Create a directory to store the binary strings if it doesn't exist
output_directory = "binary_strings"
os.makedirs(output_directory, exist_ok=True)

# Loop through the minutiae data for each image
for idx, image_data in enumerate(all_minutiae_results):
    # Serialize the minutiae data into a binary string
    binary_string = ""

    # Assuming you have a list of minutiae coordinates like [(x1, y1), (x2, y2), ...]
    minutiae_coordinates = [(minutiae.locX, minutiae.locY) for minutiae in image_data['FeaturesTerm']]

    # Create a binary string where each position corresponds to a pixel in the image
    height, width = cv2.imread(image_data['ImageName'], 0).shape
    for x in range(height):
        for y in range(width):
            if (x, y) in minutiae_coordinates:
                binary_string += "1"
            else:
                binary_string += "0"

    # Save the binary string to a text file
    binary_string_filename = os.path.join(output_directory, f"binary_string_{idx + 1}.txt")
    with open(binary_string_filename, "w") as text_file:
        text_file.write(binary_string)

print(f"All binary strings saved in the '{output_directory}' directory.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\idk\CRYPTo\fingerprint-feature-extraction-for-biometrics.ipynb Cell 30 line 2
#      <a href='vscode-notebook-cell:/d%3A/idk/CRYPTo/fingerprint-feature-extraction-for-biometrics.ipynb#X42sZmlsZQ%3D%3D?line=25'>26</a>             binary_string += "1"
#      <a href='vscode-notebook-cell:/d%3A/idk/CRYPTo/fingerprint-feature-extraction-for-biometrics.ipynb#X42sZmlsZQ%3D%3D?line=26'>27</a>         else:
# ---> <a href='vscode-notebook-cell:/d%3A/idk/CRYPTo/fingerprint-feature-extraction-for-biometrics.ipynb#X42sZmlsZQ%3D%3D?line=27'>28</a>             binary_string += "0"
#      <a href='vscode-notebook-cell:/d%3A/idk/CRYPTo/fingerprint-feature-extraction-for-biometrics.ipynb#X42sZmlsZQ%3D%3D?line=29'>30</a> # Save the binary string to a text file
#      <a href='vscode-notebook-cell:/d%3A/idk/CRYPTo/fingerprint-feature-extraction-for-biometrics.ipynb#X42sZmlsZQ%3D%3D?line=30'>31</a> binary_string_filename = os.path.join(output_directory, f"binary_string_{idx + 1}.txt")
#
# KeyboardInterrupt:

# %% [markdown]
# HOW TO GET BACK THE MINUTIAE RESULTS ?
#
# Here's a general outline of the process:
#
# 1. Read the binary string files.
#
# 2. Deserialize the binary data to obtain the structured minutiae data.
#
# 3. Use the retrieved minutiae data as needed for further processing or analysis.
